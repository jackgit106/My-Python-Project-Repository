# %% [markdown]
# <a href="https://colab.research.google.com/github/jackgit106/My-Python-Project-Repository/blob/main/1stWorksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==== SETUP: install and import libraries ====
# Run this cell once whenever you (re)connect to the runtime.

# 1. Install any libraries that are NOT built into Colab
# !pip install pandas matplotlib seaborn --quiet

# %%
# 2. Import all the core libraries you’ll use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 3. Global display options (optional)
pd.set_option("display.max_rows", 10)
sns.set(style="whitegrid")
print("Setup complete")    # output will be setup complete
# Out:
# Setup complete

# %%
# 4 Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Load the file
from google.colab import files
import pandas as pd
uploaded = files.upload()           # you chose student.csv from choose files – below tab
full_path = '/content/student.csv'    # match the name shown after upload
# Out:
#      <input type="file" id="files-4e8e0e23-ab06-4e22-aafa-f3b83ce8e570" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e8e0e23-ab06-4e22-aafa-f3b83ce8e570">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/student.csv')             # file that appears on the left 'file' pane (in Colab session)

# %%
import shutil
shutil.copy('/content/student.csv', '/content/drive/MyDrive/student.csv')
# Out:
# '/content/drive/MyDrive/student.csv'

# %%
#To see row and column numbers
print("Dataset loaded: Student.csv")
# Out:
# Dataset loaded: Student.csv

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (35, 5)

# %%
print(df.head())
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
pd.set_option('display.max_rows', None)

# %%
print(df)
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    34 non-null     object
#  2   class   34 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  33 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB
# None

# %%
print (df['name'].unique())
# Out:
# ['John Deo' 'Max Ruin' 'Arnold' 'Krish Star' 'John Mike' 'Alex John'
#  'My John Rob' 'Asruid' 'Tes Qry' 'Big John' 'Ronald' 'Recky' 'Kty' 'Bigy'
#  'Tade Row' 'Gimmy' 'Tumyu' 'Honny' 'Tinny' 'Jackly' 'Babby John' 'Reggid'
#  'Herod' 'Tiddy Now' 'Giff Tow' 'Crelea' nan 'Rojj Base' 'Tess Played'
#  'Reppy Red' 'Marry Toeey' 'Binn Rott' 'Kenn Rein' 'Gain Toe' 'Rows Noump']

# %%
sorted_df=df.sort_values(by='name')

# %%
print(sorted_df)
# Out:
#     id         name  class  mark  gender
# 5    6    Alex John   Four    55    male
# 2    3       Arnold  Three    55    male
# 7    8       Asruid   Five    85    male
# 20  21   Babby John   Four    69  female
# 9   10     Big John   Four    55  female
# 13  14         Bigy  Seven    88  female
# 31  32    Binn Rott  Seven    90  female
# 25  26       Crelea  Seven    79    male
# 33  34     Gain Toe  Seven    69    male
# 24  25     Giff Tow  Seven    88    male
# 15  16        Gimmy   Four    88    male
# 22  23        Herod  Eight    79    male
# 17  18        Honny   Five    75    male
# 19  20       Jackly   Nine    65  female
# 0    1     John Deo   Four    75  female
# 4    5    John Mike   Four    60  female
# 32  33    Kenn Rein    Six    96  female
# 3    4   Krish Star   Four    60  female
# 12  13          Kty  Seven    88  female
# 30  31  Marry Toeey   Four    88    male
# 1    2     Max Ruin  Three    85    male
# 6    7  My John Rob  Fifth    78    male
# ...

# %%
sorted_df = df.sort_values(by='name',ascending=False)

# %%
print(sorted_df)
# Out:
#     id         name  class  mark  gender
# 16  17        Tumyu    Six    54    male
# 18  19        Tinny   Nine    18    male
# 23  24    Tiddy Now  Seven    78    male
# 28  29  Tess Played  Seven    55    male
# 8    9      Tes Qry    Six    78     NaN
# 14  15     Tade Row    NaN    88    male
# 34  35   Rows Noump    Six    88  female
# 10  11       Ronald    Six    89  female
# 27  28    Rojj Base  Seven    86  female
# 29  30    Reppy Red    Six    79  female
# 21  22       Reggid  Seven    55  female
# 11  12        Recky    Six    94  female
# 6    7  My John Rob  Fifth    78    male
# 1    2     Max Ruin  Three    85    male
# 30  31  Marry Toeey   Four    88    male
# 12  13          Kty  Seven    88  female
# 3    4   Krish Star   Four    60  female
# 32  33    Kenn Rein    Six    96  female
# 4    5    John Mike   Four    60  female
# 0    1     John Deo   Four    75  female
# 19  20       Jackly   Nine    65  female
# 17  18        Honny   Five    75    male
# ...

# %%
print(sorted(df['mark'].unique()))
# Out:
# [np.int64(18), np.int64(54), np.int64(55), np.int64(60), np.int64(65), np.int64(69), np.int64(75), np.int64(78), np.int64(79), np.int64(81), np.int64(85), np.int64(86), np.int64(88), np.int64(89), np.int64(90), np.int64(94), np.int64(96)]

# %%
print(df.describe())
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
print(df.tail())
# Out:
#     id         name  class  mark  gender
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
print(df.columns)
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
print(df.dtypes)
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %%
print(df['name'].unique())
# Out:
# ['John Deo' 'Max Ruin' 'Arnold' 'Krish Star' 'John Mike' 'Alex John'
#  'My John Rob' 'Asruid' 'Tes Qry' 'Big John' 'Ronald' 'Recky' 'Kty' 'Bigy'
#  'Tade Row' 'Gimmy' 'Tumyu' 'Honny' 'Tinny' 'Jackly' 'Babby John' 'Reggid'
#  'Herod' 'Tiddy Now' 'Giff Tow' 'Crelea' nan 'Rojj Base' 'Tess Played'
#  'Reppy Red' 'Marry Toeey' 'Binn Rott' 'Kenn Rein' 'Gain Toe' 'Rows Noump']

# %%
print(df['mark'].value_counts())
# Out:
# mark
# 88    7
# 55    5
# 78    3
# 79    3
# 75    2
# 60    2
# 85    2
# 69    2
# 89    1
# 54    1
# 94    1
# 65    1
# 18    1
# 81    1
# 86    1
# 90    1
# 96    1
# Name: count, dtype: int64

# %%
num_rows = int(input("How many rows would you like to see?"))
# Out:
# How many rows would you like to see?5

# %%
print(df.head(num_rows))
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
total_columns = len(df.columns)

# %%
print(f"Total number of columns:[total_columns]")
# Out:
# Total number of columns:[total_columns]

# %%
print("First student is John Deo")
# Out:
# First student is John Deo

# %%
print('Second student is Max Ruin')
# Out:
# Second student is Max Ruin

# %%
print("It's John Deo's record")
# Out:
# It's John Deo's record

# %%
print("John Deo is in class 'Four'")
# Out:
# John Deo is in class 'Four'

# %%
print("John Deo has a mark of 75")
# Out:
# John Deo has a mark of 75

# %%
print("Max Ruin, class Three, mark 85")
# Out:
# Max Ruin, class Three, mark 85

# %%
print("Arnold is male and in class Three")
# Out:
# Arnold is male and in class Three

# %%
print("Tade Row has class missing but mark 88")
# Out:
# Tade Row has class missing but mark 88

# %%
Name = "Ali"
Age = 18
Score = 75

print(Name,Age,Score)
# Out:
# Ali 18 75

# %%
Name = "Jack"
print("Hello", Name)
# Out:
# Hello Jack

# %%
myName = "Jack"
print(myName)
print(type(myName))
print(len(myName))
# Out:
# Jack
# <class 'str'>
# 4

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
mark1 = 85
mark2 = 55
average = (mark1 + mark2) / 2
print(average)
# Out:
# 70.0

# %%
print("Hello, world!")
print("What is your name?")  # ask for their name
myName = input()
print("It is good to meet you, " + myName)
print("The length of your name is:")
print(len(myName))
print("What is your age?")  # ask for their age
myAge = input()
print("You will be " + str(int(myAge) + 1) + " in a year.")
# Out:
# Hello, world!
# What is your name?
# Jack
# It is good to meet you, Jack
# The length of your name is:
# 4
# What is your age?
# 27
# You will be 28 in a year.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
print(num1 + num2)
# Out:
# Enter first number: 98
# Enter second number: 1900
# 1998

# %%
num1 = int(input("Enter First Number:"))
num2 = int(input("Enter Second Number:"))
print(num1 + num2)
# Out:
# Enter First Number:98
# Enter Second Number:1900
# 1998
